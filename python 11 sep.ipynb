# %% [markdown]
# #Modify strings

# %%
a=' I live in Kathmandu and I am working as manager in Hotel Hilton.'

# %%
print(a)
# Out:
#  I live in Kathmandu and I am working as manager in Hotel Hilton.

# %%
a.upper()
# Out:
# ' I LIVE IN KATHMANDU AND I AM WORKING AS MANAGER IN HOTEL HILTON.'

# %%
a.lower()
# Out:
# ' i live in kathmandu and i am working as manager in hotel hilton.'

# %%
def lower(x):
 print (x.lower())

# %%
lower(a)
# Out:
#  i live in kathmandu and i am working as manager in hotel hilton.

# %%
a.strip()
# Out:
# 'I live in Kathmandu and I am working as manager in Hotel Hilton.'

# %%
a.replace('I','We')
# Out:
# ' We live in Kathmandu and We am working as manager in Hotel Hilton.'

# %%
a.replace ('Kathmandu','pokhara')
# Out:
# ' I live in pokhara and I am working as manager in Hotel Hilton.'

# %%
a
# Out:
# ' I live in Kathmandu and I am working as manager in Hotel Hilton.'

# %%
a.capitalize()
# Out:
# ' i live in kathmandu and i am working as manager in hotel hilton.'

# %%
a.split()
# Out:
# ['I',
#  'live',
#  'in',
#  'Kathmandu',
#  'and',
#  'I',
#  'am',
#  'working',
#  'as',
#  'manager',
#  'in',
#  'Hotel',
#  'Hilton.']

# %%
a.center(100)
# Out:
# '                  I live in Kathmandu and I am working as manager in Hotel Hilton.                  '

# %%
a.split(' and')

# %%
help(a.split)

# %%
help(pow)

# %% [markdown]
# # Concatenation

# %%
a='Hello'
b=' World'

# %%
d=a+b

# %%
d

# %% [markdown]
# ### String format

# %%
a='My percentage in exam was'
per=90

# %%
added_text=f'My percentage in exam was {per}'

# %%
added_text

# %%
added_text_a=f'My percentage is more than{per:.5f}'

# %%
added_text_a

# %% [markdown]
# ### Escape character

# %%
#single quotation escape
abc='She is Ram\'s mother.'

# %%
abc

# %%
abc='She is Ram\'s mother.\n Her name is Lisa.'

# %%
abc

# %%
print(abc)

# %% [markdown]
# ### Boolean Value

# %%
print(4>6)
# Out:
# False

# %%
print(4>2)
# Out:
# True

# %% [markdown]
# ### Python operators

# %%
a=100
b=50

# %%
a+b
# Out:
# 150

# %%
a-b
# Out:
# 50

# %%
a*b
# Out:
# 5000

# %%
a/b
# Out:
# 2.0

# %%
b%a
# Out:
# 50

# %%
a**2
# Out:
# 10000

# %%
a//b
# Out:
# 2

# %% [markdown]
# ## Python Assignment operator

# %%
a=4

# %%
x=a+56

# %%
x
# Out:
# 60

# %%
a+=65

# %%
print(a)
# Out:
# 69

# %% [markdown]
# ## Comparison Operator

# %%
a=60
b=50

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %%
print(a>b)
# Out:
# True

# %%
print(a<b)
# Out:
# False

# %% [markdown]
# ## Python Logical Operator

# %%
z=23

# %%
print(z>10 and z<3)
# Out:
# False

# %%
print (z>10 or z<3)
# Out:
# True
