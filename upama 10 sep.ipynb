# %%
a='I live in Kathmandu and work in school.'

# %%
print (a)
# Out:
# I live in Kathmandu and work in school.

# %%
a.lower()
# Out:
# 'i live in kathmandu and work in school.'

# %%
a.strip()
# Out:
# 'I live in Kathmandu and work in school.'

# %%
a.replace('Kathmandu','Pokhara')
# Out:
# 'I live in Pokhara and work in school.'

# %%
a.split()
# Out:
# ['I', 'live', 'in', 'Kathmandu', 'and', 'work', 'in', 'school.']

# %%
a.split('&')
# Out:
# ['I live in Kathmandu and work in school.']

# %% [markdown]
# Concatenation

# %%
a='Hello'
b='world'

# %%
d=(a)+(b)

# %%
d
# Out:
# 'Helloworld'

# %% [markdown]
# ###Escape character

# %%
abc='She is ram\'s mother'

# %%
abc
# Out:
# "She is ram's mother"

# %%
abc= 'she is Ram\'s mother and\n her mother name is Lisa.'

# %%
abc
# Out:
# "she is Ram's mother and\n her mother name is Lisa."

# %%
print (abc)
# Out:
# she is Ram's mother and
#  her mother name is Lisa.

# %%
a.center (200)
# Out:
# '                                                                                                 Hello                                                                                                  '

# %% [markdown]
# BOOLEAN VALUE

# %%
print(3<20)
# Out:
# True

# %%
a=18
b=9

# %%
a+b
# Out:
# 27

# %%
a%b
# Out:
# 0

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
y=a+9

# %%
print(y)
# Out:
# 27

# %% [markdown]
# ###comparison operator

# %%
a=35
b=65

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %% [markdown]
# Python Logical op[erator

# %%
z=12

# %%
print (z>20 and z<13)
# Out:
# False

# %%
type (z)
# Out:
# int
