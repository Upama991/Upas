# %%
import pandas as pd

# Load Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
#view first few rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #Data Understanding

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 411          412         0       3                  Hart, Mr. Henry    male
# 332          333         0       1        Graham, Mr. George Edward    male
# 365          366         0       3   Adahl, Mr. Mauritz Nils Martin    male
# 297          298         0       1     Allison, Miss. Helen Loraine  female
# 403          404         0       3   Hakkarainen, Mr. Pekka Pietari    male
# 857          858         1       1           Daly, Mr. Peter Denis     male
# 153          154         0       3  van Billiard, Mr. Austin Blyler    male
# 598          599         0       3                Boulos, Mr. Hanna    male
# 26            27         0       3          Emir, Mr. Farred Chehab    male
# 499          500         0       3               Svensson, Mr. Olof    male
#
#       Age  SibSp  Parch            Ticket      Fare    Cabin Embarked
# ...

# %%
df.sort_values(by='Age', ascending=False).head(20)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                        Svensson, Mr. Johan
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                           Duane, Mr. Frank
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
df.Fare.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
df['Fare']=df['Fare'].apply(lambda x:x*178)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket        Fare Cabin Embarked
# 0      0         A/5 21171   1290.5000   NaN        S
# 1      0          PC 17599  12688.4274   C85        C
# 2      0  STON/O2. 3101282   1410.6500   NaN        S
# 3      0            113803   9451.8000  C123        S
# ...

# %%
df ['Embarked'].replace({'S':'Southhampton','C':'Cherbourgh','Q':'Queenstowm'},inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14832\2574647761.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df ['Embarked'].replace({'S':'Southhampton','C':'Cherbourgh','Q':'Queenstowm'},inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket        Fare Cabin      Embarked
# 0      0         A/5 21171   1290.5000   NaN  Southhampton
# 1      0          PC 17599  12688.4274   C85    Cherbourgh
# 2      0  STON/O2. 3101282   1410.6500   NaN  Southhampton
# 3      0            113803   9451.8000  C123  Southhampton
# ...

# %%
df.rename(columns={'SibSp':'Sibiling_Spouse','Parch':'Parents_Child''Embarked:Port'},inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    Sibiling_Spouse  Parents_ChildEmbarked:Port            Ticket        Fare  \
# 0                1                           0         A/5 21171   1290.5000
# 1                1                           0          PC 17599  12688.4274
# 2                0                           0  STON/O2. 3101282   1410.6500
# ...

# %%
df_1=df[['Survived','Pclass','Age','Fare']]

# %%
df_1
# Out:
#      Survived  Pclass   Age        Fare
# 0           0       3  22.0   1290.5000
# 1           1       1  38.0  12688.4274
# 2           1       3  26.0   1410.6500
# 3           1       1  35.0   9451.8000
# 4           0       3  35.0   1432.9000
# ..        ...     ...   ...         ...
# 886         0       2  27.0   2314.0000
# 887         1       1  19.0   5340.0000
# 888         0       3   NaN   4174.1000
# 889         1       1  26.0   5340.0000
# 890         0       3  32.0   1379.5000
#
# [891 rows x 4 columns]

# %%
df_1.corr()
# Out:
#           Survived    Pclass       Age      Fare
# Survived  1.000000 -0.338481 -0.077221  0.257307
# Pclass   -0.338481  1.000000 -0.369226 -0.549500
# Age      -0.077221 -0.369226  1.000000  0.096067
# Fare      0.257307 -0.549500  0.096067  1.000000

# %%
df_1.quantile(0.75)
# Out:
# Survived       1.0
# Pclass         3.0
# Age           38.0
# Fare        5518.0
# Name: 0.75, dtype: float64

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
age=np.array(df['Age'])

# %%
np.isnan(age).sum()
# Out:
# 177

# %%
np.mean(df['Fare'])
# Out:
# 5732.349018406285

# %%
np.median(df['Fare'])
# Out:
# 2572.8476

# %%
np.std(df['Fare'])
# Out:
# 8840.465131169785

# %% [markdown]
# Important

# %%
df['Age_category']=np.where(df['Age']>18,'Adult','Child')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    Sibiling_Spouse  Parents_ChildEmbarked:Port            Ticket        Fare  \
# 0                1                           0         A/5 21171   1290.5000
# 1                1                           0          PC 17599  12688.4274
# 2                0                           0  STON/O2. 3101282   1410.6500
# ...

# %% [markdown]
# #handling missing values

# %%
df['Age']=df['Age'].fillna(np.mean(df['Age']))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    Sibiling_Spouse  Parents_ChildEmbarked:Port            Ticket        Fare  \
# 0                1                           0         A/5 21171   1290.5000
# 1                1                           0          PC 17599  12688.4274
# 2                0                           0  STON/O2. 3101282   1410.6500
# ...

# %%
df_grouped=df.groupby('Pclass').agg({
    'Age':['mean','median'],
    'Fare':['mean','median']})

# %%
df_grouped
# Out:
#               Age                     Fare
#              mean     median          mean     median
# Pclass
# 1       37.048118  35.000000  14979.534375  10731.175
# 2       29.866958  29.699118   3677.868601   2536.500
# 3       26.403259  29.699118   2434.247918   1432.900
